# %% [markdown]
# <a href="https://colab.research.google.com/github/playgroundtest1989/pythonTest1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir akr
# Out:
# mkdir: cannot create directory ‘akr’: File exists

# %%
ls
# Out:
# akr/  drive/  sample_data/

# %%
 # !git clone https://github.com/laxmimerit/CV-Parsing-using-Spacy-3.git
# Out:
# Cloning into 'CV-Parsing-using-Spacy-3'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 82 (delta 16), reused 5 (delta 0), pack-reused 0
# Unpacking objects: 100% (82/82), done.

# %%
# !git clone https://github.com/laxmimerit/CV-Parsing-using-Spacy-3.git
# Out:
# Cloning into 'CV-Parsing-using-Spacy-3'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 82 (delta 16), reused 5 (delta 0), pack-reused 0
# Unpacking objects: 100% (82/82), done.

# %%
# !pip install -U spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install spacy_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 53 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 9.1 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 48.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 46.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !spacy download en_core_web_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 587.7 MB 8.7 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !nvidia-smi
# Out:
# Tue Aug 16 02:16:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python -m spacy init fill-config /content/CV-Parsing-using-Spacy-3/data/training/base_config.cfg /content/CV-Parsing-using-Spacy-3/data/training/config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/CV-Parsing-using-Spacy-3/data/training/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import json
import numpy as np
from sklearn.model_selection import train_test_split


print("################  test")

cv_data = json.load(
    open('/content/CV-Parsing-using-Spacy-3/data/training/train_data.json', 'r'))

#print(cv_data)


def get_spacy_doc(file, data):
    nlp = spacy.blank('en')
    db = DocBin()

    for text, annot in tqdm(data):
        doc = nlp.make_doc(text)
        annot = annot['entities']

        ents = []
        entity_indices = []

        for start, end, label in annot:
            skip_entity = False
            for idx in range(start, end):
                if idx in entity_indices:
                    skip_entity = True
                    break
            if skip_entity == True:
                continue

            entity_indices = entity_indices + list(range(start, end))

            try:
                span = doc.char_span(start, end, label=label, alignment_mode='strict')
            except:
                continue
            if span is None:
                err_data = str([start, end]) + "  " + str(text) + "\n"
                file.write(err_data)

            else:
                ents.append(span)

        try:
            doc.ents = ents
            db.add(doc)
        except:
            pass
    return db


#print(cv_data)
train,test = train_test_split(cv_data, test_size=0.3)
print(train)
print(len(train))
print(len(test))

file = open('error.txt', 'w')

db = get_spacy_doc(file,train)
db.to_disk('/content/CV-Parsing-using-Spacy-3/data/training/train_data_ak.spacy')

db = get_spacy_doc(file,test)
db.to_disk('/content/CV-Parsing-using-Spacy-3/data/training/test_data_ak.spacy')
print(len(db.tokens))
file.close()
# Out:
# ################  test
# ...

# %%
print(train)
print(len(train))
print(len(test))
# Out:
# [['Ramakrishna Rao DevOps Consultant - Tech Mahindra Ltd  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Ramakrishna- Rao/0b57f5f9d35b9e5c  An accomplished IT Professional with 15.2 years of Competent technical expertise in solution design, architecture, system analysis, components design, development and testing of client server, Intranet/ Internet, N-tier systems in Microsoft, Java and middleware projects at Development, Support, E2E and Transition, Transformation, migration Projects at Telecom (BSS and OSS), Networking, Finance, Content Management, Healthcare, Banking domains. Extensive experience in Object-Oriented design and development, agile, DevOps, Cloud architecture, middleware, enterprise application integrations. a) Offshore Professional Summary • Expertise in process, tools maturity assessment and provides the implementation / transformation roadmaps.  • Extensive experience in the design and implementation of Continuous Integration, Continuous Delivery, Continu
# ...

# %%
file = open('error.txt', 'w')

db = get_spacy_doc(file,train)
db.to_disk('train_data_ak.spacy')

db = get_spacy_doc(file,test)
db.to_disk('test_data_ak.spacy')
print(len(db.tokens))
file.close()
# Out:
# ...
# 100%|██████████| 60/60 [00:00<00:00, 79.98it/s]
# 60

# %%
file = open('error.txt', 'w')

db = get_spacy_doc(file,train)
db.to_disk('train_data_ak.spacy')

db = get_spacy_doc(file,test)
db.to_disk('test_data_ak.spacy')
print(len(db.tokens))
file.close()

# %%
# !python -m spacy train /content/CV-Parsing-using-Spacy-3/data/training/config.cfg --output ./output --paths.train /content/CV-Parsing-using-Spacy-3/data/training/train_data_ak.spacy --paths.dev /content/CV-Parsing-using-Spacy-3/data/training/test_data_ak.spacy --gpu-id 0
# Out:
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2022-08-16 02:19:35,735] [INFO] Set up nlp object from config
# [2022-08-16 02:19:35,746] [INFO] Pipeline: ['transformer', 'ner']
# [2022-08-16 02:19:35,750] [INFO] Created vocabulary
# [2022-08-16 02:19:35,752] [INFO] Finished initializing nlp object
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
